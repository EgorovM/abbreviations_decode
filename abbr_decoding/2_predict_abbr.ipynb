# %%
import pandas as pd
import numpy as np

# %%
context_df = pd.read_csv('term_context.csv', sep='\t').dropna()

# %%
context_without_term = []

for term, context in context_df[['term', 'context']].iloc:
    context_without_term.append(context.replace(term, ' [TERM] '))
    
context_df['context_without_term'] = context_without_term

# %%
from normalizer import normalize_sentences

# %%
abbrs = set(context_df['abbreviation'].str.lower())

sentences = normalize_sentences(
    context_df['context_without_term'], 
    except_words=abbrs,
    as_sentences=False
)
clean_sentences = [" ".join([" ".join(word) for word in text]) for text in sentences]
context_df['normalized_context'] = clean_sentences
# Out:
# Cleaning sentences:   0%|          | 0/10295 [00:00<?, ?it/s]
# Normalizing words:   0%|          | 0/7039 [00:00<?, ?it/s]

# %%
context_df[context_df.abbreviation == 'Hb'].term.value_counts()
# Out:
# гемоглобин    1466
# Name: term, dtype: int64

# %%
context_df.groupby('abbreviation').term.unique().str.len().sort_values().tail(60)
# Out:
# abbreviation
# ММ      1
# МО      1
# МП      1
# МПВ     1
# МПЗ     1
# МПЭ     1
# МР      1
# МРТ     1
# МТС     1
# КК      1
# КИ      1
# КШ      1
# КВ      1
# ЖНР     1
# ЖТ      1
# ЗГТ     1
# ИА      1
# ИБС     1
# ИГ      1
# ИГХ     1
# ИИ      1
# ИКД     1
# ИЛАГ    1
# КГ      1
# ИМ      1
# ИМТ     1
# ИП      1
# ИСТ     1
# уЛП     1
# ИЦН     1
# КАГ     1
# ИФР     1
# ИЭ      1
# ИФТ     1
# МТ      2
# СТ      2
# ЖЭ      2
# в/в     2
# НЯ      2
# ОА      2
# ГД      2
# ЗНО     2
# КС      2
# ГТ      2
# БА      2
# ЛУ      2
# АГ      2
# АД      2
# ПТГ     2
# ПТ      2
# ТГ      2
# РЧА     2
# ПЖ      2
# ПЗ      2
# ИТ      2
# ПР      2
# ФЭК     2
# ДН      3
# КА      3
# ЛП      3
# Name: term, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
vectorizer = TfidfVectorizer()
char_vectorizer = CountVectorizer(analyzer='char')

points = vectorizer.fit_transform(context_df['normalized_context']).toarray()
char_points = char_vectorizer.fit_transform(context_df['abbreviation']).toarray()

# %%
import joblib

joblib.dump(vectorizer, 'context_vectorizer.joblib')
joblib.dump(char_vectorizer, 'char_vectorizer.joblib')
# Out:
# ['char_vectorizer.joblib']

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df_train, df_test, X_train, X_test, y_train, y_test = train_test_split(
    context_df,
    np.hstack((points, char_points)),
    context_df.term, 
    test_size=0.3
)

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
joblib.dump(clf, 'decoder_model.joblib')
# Out:
# ['decoder_model.joblib']

# %%
print('train accuracy:', clf.score(X_train, y_train))
print('train f1_score:', f1_score(y_train, clf.predict(X_train), average='weighted'))

print('test accuracy:', clf.score(X_test, y_test))
print('test f1_score:', f1_score(y_test, clf.predict(X_test), average='weighted'))
# Out:
# train accuracy: 1.0
# train f1_score: 1.0
# test accuracy: 0.9514405956620265
# test f1_score: 0.9374111313268304

# %%
df_test = df_test.copy()
df_test['predicted_term'] = clf.predict(X_test)
df_test['proba']= np.max(clf.predict_proba(X_test), axis=1)

df_test[df_test.predicted_term != df_test.term]
# Out:
#                    event_code mcb_code abbreviation  \
# 2127   GACAc+РAAAABl090009#AD      I10          СКФ
# 7568   GACAVпKABrAAB12:41A$AD      I10         НУЖТ
# 7807   GACAR+OAAIAAJ10:00-eAD      I10           ПЭ
# 2023   GACALфМAAGAAg120012#AB      I10          ГВК
# 8047   GACA]2&AAAAKW141014#AD      I10         ОПТГ
# 8061   GACAJ=ЙAVfAAANABАпB$AB      I10           ФН
# 7366   GACAVlсAAiAAA09:47A#AD      I10          КАГ
# 10037  GACA]4^AABAAB10:40-eAD      I10           ГА
# 1845   GACAIxoAADAAA21:34B%AD      I10           ПЗ
# 233    GACAgА9ABBAAC11:40A$AD      I10         ВГЛУ
# 6215   GACAM}xAABAAG17:00-gAD      I10           ЖТ
# 10041  GACAIокAAaAAA12:15AeAD      I10          АФС
# 2455   GACAW#ОAADAAL19:00-cAD      I10           ТГ
# 7048   GACAPOrAADAFd140014$AD      I10         СДЛА
# 3360   GACALЩэABnAAb123013#AD      I10           ИГ
# 5423   GACAe5qAABAAG103011$AD      I10          ТГВ
# 10032  GACAJ1тACIAAA12:49A%AD      I10           ГА
# 6344   GACA]`fAAgAAA13:41A#AB      I10          ОИМ
# 10291  GACADUDAAVAAq100010#AD      I10         CЗСТ
# 5414   GACAKfXABnAAK190019#AB      I10          ТГВ
# 1846   GACAJ=ЙAXoAAA16:31A$AB      I10           ПЗ
# 2331   GACALЙAAAIAAA14:58AgAD      I10          ТАБ
# 6355   GACAQrМAAKAAH120012eAD      I10         ФВЛЖ
# 2447   GACAJл>AARAAD12:00-cAD      I10           ТГ
# 9771   GACACqUAFVAAA11:07A$AB      I10           ШМ
# 311    GACAcщЮAAAAAC093010$AD      I10           АГ
# 7893   GACAU#UAAbAAF17:50A#AD      I10           ГТ
# 2446   GACA`&YAAAAAB12:00-gAD      I10           Т3
# 2024   GACAMiЫACFAAA12:34A#AD      I10          ЗНО
# 352    GACAGTXABcAAA14:12A$AB      I10           МО
# 2501   GACA[оЫAATAAA14:54AeAD      I10           ЦИ
# 10051  GACAIcЬAANAAP164017#AD      I10          СПС
# 181    GACA[дМAABAAA09:00-gAD      I10           НМ
# 8128   GACASАКADbAAA090009$AD      I10           ОА
# 2547   GACBAw%AAWAAI11:17A#AD      I10          ССС
# 10038  GACAbЛвAAAAAgNAAвГA$AD      I10           ГА
# 9824   GACAZSQAABAAA12:00-eAD      I10           ХБ
# 7040   GACAJbYABJAAA13:00A#AD      I10         СДЛА
# 8095   GACAe9WAAfAAJ16:28A&AD      I10          ПТГ
#
#                                              term  \
# 2127              скорость клубочковой фильтрации
# 7568         неустойчивая желудочковая тахикардия
# 7807                                 преэклампсия
# 2023                      гомованилиновая кислота
# 8047                            ортопантомограмма
# 8061                       фебрильная нейтропения
# 7366                          коронароангиография
# 10037                                   гонартроз
# 1845                       прогрессия заболевания
# 233              внутригрудные лимфатические узлы
# 6215                      желудочковая тахикардия
# 10041                   антифосфолипидный синдром
# 2455                                тиреоглобулин
# 7048    систолическое давление в легочной артерии
# 3360                               иммуноглобулин
# 5423                         тромбоз глубоких вен
# 10032                                   гонартроз
# 6344                      острый инфаркт миокарда
# 10291  системное заболевание соединительной ткани
# 5414                         тромбоз глубоких вен
# 1846                       прогрессия заболевания
# 2331          тонкоигольная аспирационная биопсия
# 6355             фракция выброса левого желудочка
# 2447                                тиреоглобулин
# 9771                                  шейка матки
# 311                      артериальная гипертензия
# 7893                               гормонотерапия
# 2446                                трийодтиронин
# 2024                  злокачественное образование
# 352                            морбидное ожирение
# 2501                  цитологическое исследование
# 10051                сафено-поплитеальное соустье
# 181                               недержание мочи
# 8128                                  остеоартроз
# 2547                  сердечно-сосудистая система
# 10038                                   гонартроз
# 9824                          хронический бронхит
# 7040    систолическое давление в легочной артерии
# 8095                        паратиреоидный гормон
#
#                                                  context  \
# 2127   глюкоза-10.75, алт-60, аст-145, креат-116. ско...
# 7568   на хм-экг регистрировалась пароксизмальная неу...
# 7807   23-24 недели находилась с 18-25.08.15 преэклам...
# 2023   ознакомлена. ванилииминдалевая кислота -2 гомо...
# 8047   очередной курс терапии начат 20.05.2018: ортоп...
# 8061   степени, нейтропения 3-4 степени. фебрильная н...
# 7366   стационарах города, в 2015г выполнялась корона...
# 10037  делали денситометрию - остеопороз, есть гонарт...
# 1845   патогенетической, поддерживающей терапии, посл...
# 233    и сегментарные бронхи проходимы&#59;- внутригр...
# 6215   не получено. спровоцирована неустойчивая желуд...
# 10041  обследовании получены данные за антифосфолипид...
# 2455   к тиреоглоубилну- 94,76 кровь на тиреоглобулин...
# 7048   мм, рнт-436 мсек), систолическое давление в ле...
# 3360   м- от 17.06.2019- 6.97 г/л. иммуноглобулин g о...
# 5423   консультирована сосудистым хирургом диагноз: т...
# 10032  образование левого надпочечника, гормонально н...
# 6344   нижне-боковой стенке лж. верифицирован острый ...
# 10291  критериальных данных за системное заболевание ...
# 5414   заключение: данных за тромбоз тромбоз глубоких...
# 1846   у пациентки наблюдается молекулярная прогресси...
# 2331   14*8 мм. была выполнена тонкоигольная аспираци...
# 6355   перфузионная офэкт миокарда: фракция выброса л...
# 2447   от 23.03.15: ттг-1,38, св т4-13,58, тиреоглобу...
# 9771   е.л.: осмотр в зеркалах: шейка матки плотная, ...
# 311    беременных миксоматозная дегенерация мк артери...
# 7893   течение 1 года пациенту проводилась гормонотер...
# 2446   св тироксин 16,1 , св трийодтиронин 3,07 от 20...
# 2024   на фгдс было выявлено злокачественное образова...
# 352    сопутствующей патологии имеет место морбидное ...
# 2501   левого надключичного лимфоузла . цитологическо...
# 10051  vsm- iii степени. 4. сафено-поплитеальное соус...
# 181    до 140\90ммртст жалобы на недержание мочи .пол...
# 8128   дуз, эутиреоз. правосторонний плече-лопаточный...
# 2547   железа : не увеличена сердечно-сосудистая сист...
# 10038  хирургического лечения. на рентгенограмме двух...
# 9824   диабет ii типа: компенсированный хронический б...
# 7040   2 степени. расчетное систолическое давление в ...
# 8095   ммоль/л (2.15 - 2.65), паратиреоидный гормон 5...
#
#                                     context_without_term  \
# 2127   глюкоза-10.75, алт-60, аст-145, креат-116.  [T...
# 7568   на хм-экг регистрировалась пароксизмальная  [T...
# 7807   23-24 недели находилась с 18-25.08.15  [TERM] ...
# 2023   ознакомлена. ванилииминдалевая кислота -2  [TE...
# 8047   очередной курс терапии начат 20.05.2018:  [TER...
# 8061   степени, нейтропения 3-4 степени.  [TERM]  3ст...
# 7366   стационарах города, в 2015г выполнялась  [TERM...
# 10037  делали денситометрию - остеопороз, есть  [TERM...
# 1845   патогенетической, поддерживающей терапии, посл...
# 233    и сегментарные бронхи проходимы&#59;-  [TERM] ...
# 6215   не получено. спровоцирована неустойчивая  [TER...
# 10041  обследовании получены данные за  [TERM]  2009г...
# 2455   к тиреоглоубилну- 94,76 кровь на  [TERM]  не с...
# 7048   мм, рнт-436 мсек),  [TERM]  допплеровским мето...
# 3360   м- от 17.06.2019- 6.97 г/л.  [TERM]  g от 17.0...
# 5423   консультирована сосудистым хирургом диагноз:  ...
# 10032  образование левого надпочечника, гормонально н...
# 6344   нижне-боковой стенке лж. верифицирован  [TERM]...
# 10291  критериальных данных за  [TERM]  нет. рекоменд...
# 5414   заключение: данных за тромбоз  [TERM]  н/к не ...
# 1846   у пациентки наблюдается молекулярная  [TERM]  ...
# 2331   14*8 мм. была выполнена  [TERM]  узла, по данн...
# 6355     перфузионная офэкт миокарда:  [TERM]  в покое -
# 2447   от 23.03.15: ттг-1,38, св т4-13,58,  [TERM]  м...
# 9771   е.л.: осмотр в зеркалах:  [TERM]  плотная, сли...
# 311    беременных миксоматозная дегенерация мк  [TERM...
# 7893   течение 1 года пациенту проводилась  [TERM]  в...
# 2446   св тироксин 16,1 , св  [TERM]  3,07 от 2016 го...
# 2024   на фгдс было выявлено  [TERM]  желудка. 01.04....
# 352    сопутствующей патологии имеет место  [TERM]  (...
# 2501   левого надключичного лимфоузла .  [TERM]  №197...
# 10051  vsm- iii степени. 4.  [TERM]  слева несостояте...
# 181    до 140\90ммртст жалобы на  [TERM]  .полиостеоа...
# 8128   дуз, эутиреоз. правосторонний плече-лопаточный...
# 2547   железа : не увеличена  [TERM]  : пульс: 72 уд....
# 10038  хирургического лечения. на рентгенограмме двух...
# 9824   диабет ii типа: компенсированный  [TERM]  кури...
# 7040               2 степени. расчетное  [TERM]  - 35 мм
# 8095   ммоль/л (2.15 - 2.65),  [TERM]  51.30 pg/ml (1...
#
#                                       normalized_context  \
# 2127     глюкоза алта аста креат term по формула ckd epi
# 7568   на хм экг регистрироваться пароксизмальный ter...
# 7807   неделя находиться с term лёгкий степень в ж к ...
# 2023   ознакомить ванилииминдалевый кислота term гидр...
# 8047   очередной курс терапия начать term от патологи...
# 8061   степень нейтропение степень term ст с разрешен...
# 7366   стационар город в г выполняться term в нмица а...
# 10037  делать денситометрия остеопороз есть term стад...
# 1845   патогенетический поддерживать терапия последни...
# 233    и сегментарный бронх проходимый term не увелич...
# 6215   не получить спровоцировать неустойчивый term и...
# 10041  обследование получить дать за term г повторный...
# 2455   к тиреоглоубилна кровь на term не сдать в пояс...
# 7048       мм рнт мсек term допплеровский метод измерить
# 3360                              м от г л term g от г л
# 5423   консультировать сосудистый хирург диагноз term...
# 10032  образование левый надпочечник гормональный неа...
# 6344   нижний боков стенка лж верифицировать term а т...
# 10291  критериальный данные за term нет рекомендовать...
# 5414   заключение данные за тромбоз term н к не получ...
# 1846   у пациентка наблюдаться молекулярный term с на...
# 2331   мм быть выполнить term узел по данные цитологи...
# 6355             перфузионный офэкт миокард term в покой
# 2447               от ттг св так term менее ттг кровь от
# 9771   быть л осмотр в зеркало term плотный слизистый...
# 311    беременная миксоматозный дегенерация мк term г...
# 7893   течение год пациент проводиться term в режим м...
# 2446                  св тироксин св term от год сегодня
# 2024               на фгдс быть выявить term желудок г в
# 352    сопутствовать патология иметь место term имт з...
# 2501                левый надключичный лимфоузел term от
# 10051  vsm iii степень  term слева несостоятельный гл...
# 181    до ммртст жалоба на term полиостеоартроз в теч...
# 8128   дуз эутиреоз правосторонний плечо лопаточный п...
# 2547              железо не увеличить term пульс уд мина
# 10038  хирургический лечение на рентгенограмма двухст...
# 9824   диабет ii тип компенсировать term курильщик по...
# 7040                           степень расчётный term мм
# 8095                                  ммоль л term pg ml
#
#                              predicted_term  proba
# 2127                             холестерин   0.24
# 7568                желудочковая тахикардия   0.27
# 7807                     эндопротезирование   0.20
# 2023                         коронарография   0.52
# 8047                            паратгормон   0.24
# 8061                 фибрилляция предсердий   0.11
# 7366                            ангиография   0.37
# 10037                           ангиография   0.42
# 1845                            поле зрения   0.15
# 233                      лимфатические узлы   0.44
# 6215   неустойчивая желудочковая тахикардия   0.30
# 10041                 физическая активность   0.25
# 2455                  гипотензивная терапия   0.41
# 7048            давление в легочной артерии   0.39
# 3360           гистологическое исследование   0.51
# 5423                  гипотензивная терапия   0.26
# 10032              артериальная гипертензия   0.37
# 6344                       инфаркт миокарда   0.42
# 10291                  синусовая тахикардия   0.23
# 5414                  гипотензивная терапия   0.28
# 1846                            поле зрения   0.17
# 2331              антибактериальная терапия   0.32
# 6355                        левый желудочек   0.21
# 2447                            паратгормон   0.23
# 9771                       инфаркт миокарда   0.16
# 311                             ангиография   0.56
# 7893                  гипотензивная терапия   0.77
# 2446                               тироксин   0.13
# 2024                                  аорта   0.22
# 352                        инфаркт миокарда   0.14
# 2501           гистологическое исследование   0.20
# 10051                        синусовый ритм   0.11
# 181                        инфаркт миокарда   0.11
# 8128                                  аорта   0.50
# 2547                         синусовый ритм   0.29
# 10038                           ангиография   0.33
# 9824                гипертоническая болезнь   0.18
# 7040            давление в легочной артерии   0.45
# 8095                            паратгормон   0.58

# %% [markdown]
# - Улучшить задачку какую нибудь

# %%
class AbbreviationDecoder:
    def __init__(self):
        self.context_vectorizer = joblib.load('context_vectorizer.joblib')
        self.char_vectorizer = joblib.load('char_vectorizer.joblib')
        self.model = joblib.load('decoder_model.joblib')
    
    def _normalize_sentences(self, sentences):
        sentences = normalize_sentences(
            sentences, 
            except_words=abbrs,
        )
        clean_sentences = [" ".join([" ".join(word) for word in text]) for text in sentences]
        
        return clean_sentences
    
    def _get_features(self, context, abbreviation):
        if isinstance(context, str):
            context = [context]
            abbreviation = [abbreviation]
            
        context = self._normalize_sentences(context)
            
        context_features = vectorizer.transform(context).toarray()
        abbr_features = char_vectorizer.transform(abbreviation).toarray()

        features = np.hstack((context_features, abbr_features))

        return features

    def predict(self, abbreviation, context):
        features = self._get_features(context, abbreviation)
        return self.model.predict(features)

# %% [markdown]
# ### Evaulation

# %%
records_df = pd.read_csv('../data/I10_anamnesis.csv', sep='\t',)

# %%
records_df[records_df.RecordEMC.str.findall(' КТ ').str.len() != 0].RecordEMC.iloc[0]
# Out:
# "<w id='GACAh;' > <v id='AA~1;' > ОНМК отрицает. Считает себя больной с 2012 года, когда стали беспокоить вышеуказанные симптомы. Стентирование левой ВСА от 2012 года. По данным КТ от 2020 года: стеноз ПВСА 90%. Настоящая госпитализация для стентирования ПВСА </v> </w>"

# %%
decoder = AbbreviationDecoder()

# %%
decoder.predict('ЛП', 'воспалительный изменение')
# Out:
# Cleaning sentences:   0%|          | 0/1 [00:00<?, ?it/s]
# Normalizing words:   0%|          | 0/2 [00:00<?, ?it/s]
# array(['люмбальная пункция'], dtype=object)

# %% [markdown]
# может ли являтся аббревиатура настоящей аббревиатурой для слова
